# %% [markdown]
# <a href="https://colab.research.google.com/github/berilldindar/Image-Processing-Local-Thresholding/blob/main/LocalThresholding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img=cv2.imread("leopar.jpg",0)

ret1,th1=cv2.threshold(img.copy(),127,255,cv2.THRESH_BINARY)
ret2,th2=cv2.threshold(img.copy(),0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
titles=["ORIJINAL","THRESHOLD","OTSU"]
images=[img,th1,th2]

plt.figure(figsize=(10,10))
for i in range(3):
    plt.subplot(3,3,i+1)
    plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
import image_slicer
from PIL import ImageDraw, ImageFont
import numpy as np
import cv2 
from matplotlib import pyplot as plt

from image_slicer import slice

slice('leopar.jpg', 9)


img=cv2.imread("leopar_01_01.png",0)
img2=cv2.imread("leopar_01_02.png",0)
img3=cv2.imread("leopar_01_03.png",0)
img4=cv2.imread("leopar_02_01.png",0)
img5=cv2.imread("leopar_02_02.png",0)
img6=cv2.imread("leopar_02_03.png",0)
img7=cv2.imread("leopar_03_01.png",0)
img8=cv2.imread("leopar_03_02.png",0)
img9=cv2.imread("leopar_03_03.png",0)
th1=cv2.adaptiveThreshold(img.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,1)
#th1=cv2.adaptiveThreshold(img.copy(), 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,3)
#th2=cv2.adaptiveThreshold(img2.copy(), 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,17,3)
th2=cv2.adaptiveThreshold(img2.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,17,3)
th3=cv2.adaptiveThreshold(img3.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,1)
th4=cv2.adaptiveThreshold(img4.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,1)
#th5=cv2.adaptiveThreshold(img5.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,7,3,cv2.INTER_AREA)
th5=cv2.adaptiveThreshold(img5.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,17,3)
th6=cv2.adaptiveThreshold(img6.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,17,3)
th7=cv2.adaptiveThreshold(img7.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,19,1)
#th7=cv2.adaptiveThreshold(img7.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,5,3)
th8=cv2.adaptiveThreshold(img8.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,17,3)
th9=cv2.adaptiveThreshold(img9.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,17,3)



titles=["r1","r2","r3","r4","r5","r6","r7","r8","r9"]
images=[th1,th2,th3,th4,th5,th6,th7,th8,th9]

plt.figure(figsize=(10,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img=cv2.imread("farkli.jpg",0)

ret1,th1=cv2.threshold(img.copy(),127,255,cv2.THRESH_BINARY)
ret2,th2=cv2.threshold(img.copy(),0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
titles=["ORIJINAL","THRESHOLD","OTSU"]
images=[img,th1,th2]

plt.figure(figsize=(10,10))
for i in range(3):
    plt.subplot(3,3,i+1)
    plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
import image_slicer
from PIL import ImageDraw, ImageFont
import numpy as np
import cv2 
from matplotlib import pyplot as plt

from image_slicer import slice

slice('farkli.jpg', 9)


img=cv2.imread("farkli_01_01.png",0)
img2=cv2.imread("farkli_01_02.png",0)
img3=cv2.imread("farkli_01_03.png",0)
img4=cv2.imread("farkli_02_01.png",0)
img5=cv2.imread("farkli_02_02.png",0)
img6=cv2.imread("farkli_02_03.png",0)
img7=cv2.imread("farkli_03_01.png",0)
img8=cv2.imread("farkli_03_02.png",0)
img9=cv2.imread("farkli_03_03.png",0)
th1=cv2.adaptiveThreshold(img.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,33,9)

#th2=cv2.adaptiveThreshold(img2.copy(), 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,17,3)
th2=cv2.adaptiveThreshold(img2.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,29,3)
re3,th3=cv2.threshold(img3.copy(),0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#th3=cv2.adaptiveThreshold(img3.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,1)
re4,th4=cv2.threshold(img4.copy(),0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#th4=cv2.adaptiveThreshold(img4.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,19,1)
#th5=cv2.adaptiveThreshold(img5.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,7,3,cv2.INTER_AREA)
th5=cv2.adaptiveThreshold(img5.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,31,5)
re6,th6=cv2.threshold(img6.copy(),0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#re7,th7=cv2.threshold(img7.copy(),0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
th7=cv2.adaptiveThreshold(img7.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,33,9)
th8=cv2.adaptiveThreshold(img8.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,33,9)
th9=cv2.adaptiveThreshold(img9.copy(), 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,31,7)



titles=["r1","r2","r3","r4","r5","r6","r7","r8","r9"]
images=[th1,th2,th3,th4,th5,th6,th7,th8,th9]

plt.figure(figsize=(10,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img=cv2.imread("beyin.jpg",0)

ret1,th1=cv2.threshold(img.copy(),127,255,cv2.THRESH_BINARY)
ret2,th2=cv2.threshold(img.copy(),0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
titles=["ORIJINAL","THRESHOLD","OTSU"]
images=[img,th1,th2]

plt.figure(figsize=(10,10))
for i in range(3):
    plt.subplot(3,3,i+1)
    plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
import image_slicer
from PIL import ImageDraw, ImageFont
import numpy as np
import cv2 
from matplotlib import pyplot as plt

from image_slicer import slice

slice('beyin.jpg', 9)


img=cv2.imread("beyin_01_01.png",0)
img2=cv2.imread("beyin_01_02.png",0)
img3=cv2.imread("beyin_01_03.png",0)
img4=cv2.imread("beyin_02_01.png",0)
img5=cv2.imread("beyin_02_02.png",0)
img6=cv2.imread("beyin_02_03.png",0)
img7=cv2.imread("beyin_03_01.png",0)
img8=cv2.imread("beyin_03_02.png",0)
img9=cv2.imread("beyin_03_03.png",0)
#th1=cv2.adaptiveThreshold(img.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,1)
th1=cv2.adaptiveThreshold(img.copy(), 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,57,1)
#th2=cv2.adaptiveThreshold(img2.copy(), 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,17,3)
th2=cv2.adaptiveThreshold(img2.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,51,3)
th3=cv2.adaptiveThreshold(img3.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,51,3)
#th3=cv2.adaptiveThreshold(img3.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,1)
th4=cv2.adaptiveThreshold(img4.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,47,5)
#th5=cv2.adaptiveThreshold(img5.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,7,3,cv2.INTER_AREA)
th5=cv2.adaptiveThreshold(img5.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,43,7)
th6=cv2.adaptiveThreshold(img6.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,43,3)
th7=cv2.adaptiveThreshold(img7.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,37,3)
#th7=cv2.adaptiveThreshold(img7.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,5,3)
th8=cv2.adaptiveThreshold(img8.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,61,3)
th9=cv2.adaptiveThreshold(img9.copy(), 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,37,3)



titles=["r1","r2","r3","r4","r5","r6","r7","r8","r9"]
images=[th1,th2,th3,th4,th5,th6,th7,th8,th9]

plt.figure(figsize=(10,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([])
    plt.yticks([])
plt.show()
